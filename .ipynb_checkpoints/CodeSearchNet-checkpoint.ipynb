# %%
import pandas as pd
import json

# %%
data = pd.read_pickle("code_search_net_format.pkl")

# %%
data.loc[data['code'] != "None"]
# Out:
#                                             docstring  \
# 0                             Drop Down Menu Fade Out
# 1                             Drop Down Menu Fade Out
# 2                             Drop Down Menu Fade Out
# 3                             Drop Down Menu Fade Out
# 0                   Menu breaks when it shouldn&#39;t
# ..                                                ...
# 0   https post in javascript similar to the curl w...
# 1   https post in javascript similar to the curl w...
# 2   https post in javascript similar to the curl w...
# 3   https post in javascript similar to the curl w...
# 4   https post in javascript similar to the curl w...
#
#                                                  code  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 0                                                None
# ..                                                ...
# 0   \nconst request = require('request');\n\nconst...
# 1   \nconst request = require('request');\n\nconst...
# 2   \nconst request = require('request');\n\nconst...
# 3   \nconst request = require('request');\n\nconst...
# 4   \nconst request = require('request');\n\nconst...
#
#                                           code_tokens  \
# 0
# 1
# 2
# 3
# 0
# ..                                                ...
# 0   [const,request,=,require,(,'request',),;,const...
# 1   [const,request,=,require,(,'request',),;,const...
# 2   [const,request,=,require,(,'request',),;,const...
# 3   [const,request,=,require,(,'request',),;,const...
# 4   [const,request,=,require,(,'request',),;,const...
#
#                                      docstring_tokens repo path func_name  \
# 0                           [Drop,Down,Menu,Fade,Out]
# 1                           [Drop,Down,Menu,Fade,Out]
# 2                           [Drop,Down,Menu,Fade,Out]
# 3                           [Drop,Down,Menu,Fade,Out]
# 0            [Menu,breaks,when,it,shouldn,&,#,39,;,t]
# ..                                                ...  ...  ...       ...
# 0   [https,post,in,javascript,similar,to,the,curl,...
# 1   [https,post,in,javascript,similar,to,the,curl,...
# 2   [https,post,in,javascript,similar,to,the,curl,...
# 3   [https,post,in,javascript,similar,to,the,curl,...
# 4   [https,post,in,javascript,similar,to,the,curl,...
#
#       language                                    original_string
# 0   javascript                            Drop Down Menu Fade Out
# 1   javascript                            Drop Down Menu Fade Out
# 2   javascript                            Drop Down Menu Fade Out
# 3   javascript                            Drop Down Menu Fade Out
# 0   javascript                  Menu breaks when it shouldn&#39;t
# ..         ...                                                ...
# 0   javascript  https post in javascript similar to the curl w...
# 1   javascript  https post in javascript similar to the curl w...
# 2   javascript  https post in javascript similar to the curl w...
# 3   javascript  https post in javascript similar to the curl w...
# 4   javascript  https post in javascript similar to the curl w...
#
# [119320 rows x 9 columns]

# %%
data.index()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-e615eec1a442> in <module>
# ----> 1 data.index()
#
# TypeError: 'Int64Index' object is not callable

# %%
data.reset_index().index
# Out:
# RangeIndex(start=0, stop=119320, step=1)

# %%
result = data.to_json(orient="records")
parsed = json.loads(result)
json.dumps(parsed, indent=4) 
with open('code_search_net.json', 'w') as outfile:
    json.dump(parsed, outfile)

# %%
data
