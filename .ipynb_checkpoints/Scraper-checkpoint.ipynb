# %%
from bs4 import BeautifulSoup
import urllib
import pandas as pd
import json
import numpy as np
import requests
import re

# %%
import time

# %%
data = pd.read_pickle("tags_3_1_june")

# %%
data
# Out:
#           tags  question_id  \
# 0   javascript     68135672
# 0   javascript     53885245
# 1       jquery     53885245
# 2   datatables     53885245
# 0   javascript     67985576
# ..         ...          ...
# 0   javascript     33428974
# 1       jquery     33428974
# 2         html     33428974
# 3          url     33428974
# 4       mobile     33428974
#
#                                                 title         label
# 0    How to create a functional javascript search bar    search bar
# 0                  jQuery DataTables: hide search bar    search bar
# 1                  jQuery DataTables: hide search bar    search bar
# 2                  jQuery DataTables: hide search bar    search bar
# 0   How to filter table rows with search bar in Re...    search bar
# ..                                                ...           ...
# 0   How to code a link for social media site: mobi...  social media
# 1   How to code a link for social media site: mobi...  social media
# 2   How to code a link for social media site: mobi...  social media
# 3   How to code a link for social media site: mobi...  social media
# 4   How to code a link for social media site: mobi...  social media
#
# [5055 rows x 4 columns]

# %%
#  $$$$$$$$$$$$$$$$$$$$$$$$$$$$$
unfinished = set()
contain_values = data[data['answer_code'].str.contains('$$$$$$$$$$$$$$$$$$$$$$$$$$$$$')]
print (contain_values["question_id"].unique())
# Out:
# [36871635 61619681 61662353 ... 59187666 36262360 59179247]

# %%
len(contain_values["question_id"].unique())
# Out:
# 32597

# %%
data.to_pickle("capstone_scraped.pkl")

# %%
list(data["tags"].unique())
# Out:
# ['javascript',
#  'jquery',
#  'html',
#  'css',
#  'google-apps-script',
#  'google-sheets',
#  'web',
#  'tampermonkey',
#  'zurb-foundation',
#  'd3.js',
#  'svg',
#  'bar-chart',
#  'dropdown',
#  'vuejs2',
#  'vuetify.js',
#  'jquery-ui',
#  'autocomplete',
#  'jquery-autocomplete',
#  'angular',
#  'twitter-bootstrap',
#  'menu',
#  'adminlte',
#  'bootstrap-4',
#  'reactjs',
#  'typescript',
#  'vue.js',
#  'navigation-drawer',
#  'menuitem',
#  'hamburger-menu',
#  'angular7',
#  'angular-components',
#  'hyperlink',
#  'toggle',
#  'google-chrome-extension',
#  'contextmenu',
#  'ajax',
#  'fetch',
#  'bootstrap-modal',
#  'amcharts',
#  'amcharts4',
#  'html-lists',
#  'nav',
#  'kendo-ui',
#  'kendo-grid',
#  'react-native',
#  'expo',
#  'modal-dialog',
#  'angularjs',
#  'select',
#  'angularjs-material',
#  'jsp',
#  'wysiwyg',
#  'draftjs',
#  'draft-js-plugins',
#  'php',
#  'laravel',
#  'formik',
#  'semantic-ui-react',
#  'node.js',
#  'electron',
#  'renderer',
#  'scroll',
#  'material-ui',
#  'material-design',
#  'material-components',
#  'material-components-web',
#  'mdc-components',
#  'tabs',
#  'react-router',
#  'z-index',
#  'responsive-design',
#  'drop-down-menu',
#  'label',
#  'wordpress',
#  'react-hooks',
#  'react-functional-component',
#  'single-page-application',
#  'vue-router',
#  'antd',
#  'class',
#  'android',
#  'navbar',
#  'bots',
#  'discord',
#  'discord.js',
#  'jsx',
#  'react-router-dom',
#  'tabulator',
#  'click',
#  'web-applications',
#  'xml',
#  'model-view-controller',
#  'combobox',
#  'sapui5',
#  'sharepoint',
#  'ms-project',
#  'json',
#  'recursion',
#  'button',
#  'navigationbar',
#  'submenu',
#  'telegram',
#  'telegram-bot',
#  'function',
#  'inspinia',
#  'loops',
#  'object',
#  'shinydashboard',
#  'shinyjs',
#  'tailwind-css',
#  'slide',
#  'jquery-ui-autocomplete',
#  'mouseevent',
#  'p5.js',
#  'checkbox',
#  'navigation',
#  'use-effect',
#  'perl',
#  'cgi',
#  'window.open',
#  'qml',
#  'text-to-speech',
#  'getelementbyid',
#  'frameworks',
#  'accordion',
#  'reactstrap',
#  'puppeteer',
#  'browser-automation',
#  'fade',
#  'prompt',
#  'user-interface',
#  'css-position',
#  'url',
#  'mysql',
#  'ckeditor',
#  'ckeditor4.x',
#  'collapse',
#  'arrays',
#  'leaflet',
#  'viewport',
#  'dom',
#  'jquery-mobile',
#  'mongodb',
#  'option',
#  'sticky',
#  'google-chrome',
#  'google-chrome-app',
#  'full-text-search',
#  'off-canvas-menu',
#  'sidenav',
#  'cursor',
#  'ionic-framework',
#  'angular-material',
#  'java',
#  'tinymce',
#  'javafx-2',
#  'angular-ngselect',
#  'ios',
#  'share',
#  'state',
#  'google-analytics',
#  'event-handling',
#  'google-tag-manager',
#  'dom-events',
#  'atlaskit',
#  'jstree',
#  'styled-components',
#  'asp.net-core-mvc',
#  'google-custom-search',
#  'forms',
#  'onchange',
#  'primeng',
#  'ecmascript-6',
#  'ecmascript-7',
#  'math',
#  'google-maps',
#  'google-maps-api-3',
#  'ng-class',
#  'django',
#  'c#',
#  'asp.net-mvc',
#  'rotativa',
#  'odoo-12',
#  'list',
#  'c++',
#  'taskbar',
#  'uinavigationbar',
#  'xhtml-1.0-strict',
#  'twitter-bootstrap-3',
#  'photoswipe',
#  'react-select',
#  'fonts',
#  'nuxt.js',
#  'jhipster',
#  'less',
#  'monaco-editor',
#  'semantic-ui',
#  'gatsby',
#  'silverstripe',
#  'mmenu',
#  'getjson',
#  'routing',
#  'blogger',
#  'google-font-api',
#  'sass',
#  'superfish',
#  'firefox',
#  'three.js',
#  'dat.gui',
#  'hash',
#  'sections',
#  'google-chrome-devtools',
#  'internet-explorer',
#  'ejs',
#  'metronic',
#  'avatar',
#  'plugins',
#  'listbox',
#  'adobe-indesign',
#  'slickgrid',
#  'cypress',
#  'animation',
#  'fullcalendar',
#  'inline',
#  'right-click',
#  'mobile',
#  'maps',
#  'here-api',
#  'here-maps-rest',
#  'summernote',
#  'frontend',
#  'iframe',
#  'kiosk-mode',
#  'onclick',
#  'keyboard',
#  'focus',
#  'jquery-mobile-navbar',
#  'this',
#  'undefined',
#  'megamenu',
#  'velo',
#  'asp.net-mvc-4',
#  'gulp',
#  'uncss',
#  'extjs',
#  'extjs5',
#  'oxygenxml',
#  'extjs6',
#  'parameters',
#  'internet-explorer-11',
#  'strapi',
#  'headless-cms',
#  'redux',
#  'command-line-interface',
#  'bokeh',
#  'react-bootstrap',
#  'swiper',
#  'angular8',
#  'jquery-ui-accordion',
#  'datatable',
#  'datatables',
#  'tizen',
#  'tizen-web-app',
#  'samsung-galaxy-gear',
#  'indexing',
#  'selectedindex',
#  'joomla',
#  'responsive',
#  'css-animations',
#  'bookmarklet',
#  'python',
#  'slicknav',
#  'accessibility',
#  'wcag',
#  'flask',
#  'cross-browser',
#  'ribbon',
#  'timer',
#  'windows',
#  'menubar',
#  'titlebar',
#  'center',
#  'highcharts',
#  'toolbar',
#  'jsfiddle',
#  'camera',
#  'jquery-selectors',
#  'jquery-events',
#  'slider',
#  'mapping',
#  'css-shapes',
#  'color-picker',
#  'events',
#  'tinymce-3',
#  'stackblitz',
#  'font-awesome',
#  'fullpage.js',
#  'video',
#  'youtube',
#  'performance',
#  'botframework',
#  'bottomnavigationview',
#  'android-bottomnavigationview',
#  'browser',
#  'resize',
#  'greasemonkey',
#  'popupmenu',
#  'screen',
#  'vue-component',
#  'sorting',
#  'html-select',
#  'intersection',
#  'intersection-observer',
#  'excel',
#  'vba',
#  'web-scraping',
#  'selector',
#  'validation',
#  'css-transitions',
#  'listener',
#  'filter',
#  'safari',
#  'visual-studio-code',
#  'progressive-web-apps',
#  'selenium',
#  'selenium-webdriver',
#  'react-navigation',
#  'show-hide',
#  'stoppropagation',
#  'bootstrap-select',
#  'side-menu',
#  'mobile-webkit',
#  'iphone',
#  'ipad',
#  'mobile-safari',
#  'google-places-api',
#  'ag-grid',
#  'ag-grid-angular',
#  'styles',
#  'materialize',
#  'user-experience',
#  'ionic4',
#  'xslt',
#  'href',
#  'login',
#  'server',
#  'ruby-on-rails',
#  'ruby',
#  'ruby-on-rails-5',
#  'angular-material-6',
#  'popup',
#  'mailchimp',
#  'popupwindow',
#  'websocket',
#  'portfolio',
#  'search',
#  'load',
#  'gzip',
#  'for-loop',
#  'bulma',
#  'netlify',
#  'atom-editor',
#  'vuex',
#  'hide',
#  'custom-directive',
#  'magnification',
#  'printing',
#  'select-options',
#  'dom-traversal',
#  'dom-selection',
#  'shiny',
#  'polymer',
#  'custom-element',
#  'lit-element',
#  'jquery-chosen',
#  'babeljs',
#  'api',
#  'settimeout',
#  'node-telegram-bot-api',
#  'tags',
#  'onselect',
#  'asp.net',
#  'typeahead',
#  'typeahead.js',
#  'dashcode',
#  'r',
#  'icons',
#  'custom-post-type',
#  'lua',
#  'hover',
#  'ngfor',
#  'google-maps-markers',
#  'ionic3',
#  'each',
#  'extendscript',
#  'flexbox',
#  'jasmine',
#  'protractor',
#  'e2e-testing',
#  'ruby-on-rails-4',
#  'twig',
#  'drupal-8',
#  'express',
#  'pug',
#  'react-native-ios',
#  'react-native-popup-menu',
#  'visibility',
#  'storefront',
#  'extjs4',
#  'angular-ui-router',
#  'file-upload',
#  'lodash',
#  'raphael',
#  'web-accessibility',
#  'transition',
#  'jaws-screen-reader',
#  'jgraph',
#  'nested',
#  'jstree-dnd',
#  'jstree-search',
#  'firefox-addon',
#  'firefox-webextensions',
#  'smooth-scrolling',
#  'ui-select',
#  'meteor',
#  'underscores-wp',
#  'asp.net-core',
#  'daterangepicker',
#  'handsontable',
#  'google-apps-script-addon',
#  'netsuite',
#  'suitescript',
#  'advanced-custom-fields',
#  'gsap',
#  'konvajs',
#  'konvajs-reactjs',
#  'mobile-website',
#  'radio-button',
#  'react-redux',
#  'data-binding',
#  'wordpress-theming',
#  'text',
#  'google-sites-2016',
#  'codeigniter',
#  'codeigniter-3',
#  'jestjs',
#  'enzyme',
#  'python-3.x',
#  'overlay',
#  'angular-ui-bootstrap',
#  'processing',
#  'jquery-ui-selectmenu',
#  'tabletop.js',
#  'carousel',
#  'multidimensional-array',
#  'tinymce-4',
#  'woocommerce',
#  'jquery-select2',
#  'webkit',
#  'jquery-ui-tooltip',
#  'dojo',
#  'slidetoggle',
#  'javascript-objects',
#  'arrow-functions',
#  'user-input',
#  'adobe',
#  'adobe-bridge',
#  'drupal-7',
#  'optimization',
#  'unicode',
#  'wheelnav.js',
#  'responsive-navigation',
#  'joomla3.8',
#  'input',
#  'slidedown',
#  'slideup',
#  'asp-classic',
#  'reselect',
#  'firefox-addon-sdk',
#  'automation',
#  'knockout.js',
#  'knockout-3.0',
#  'browser-action',
#  'sidebar',
#  'getuikit',
#  'oracle-apex',
#  'oracle-apex-5.1',
#  'pebble-watch',
#  'pebble-js',
#  'textarea',
#  'sharepoint-2010',
#  'addeventlistener',
#  'copy-paste',
#  'microsoft-edge-extension',
#  'if-statement',
#  'xcode',
#  'cordova',
#  'smartmenus',
#  'web-deployment',
#  'selection',
#  'web-frontend',
#  'datagrid',
#  'extjs4.2',
#  'html-table',
#  'mysqli',
#  'pdo',
#  'extjs6-classic',
#  'event-bubbling',
#  'typo3',
#  'angularjs-ng-repeat',
#  'drag-and-drop',
#  'draggable',
#  'hammer.js',
#  'ms-word',
#  'office-js',
#  'office-addins',
#  'word-2013',
#  'togglebutton',
#  'outlook',
#  'outlook-addin',
#  'outlook-api',
#  'sumoselect.js',
#  'web-component',
#  'shadow-dom',
#  'thymeleaf',
#  'delay',
#  'infinite',
#  'commandbar',
#  'office-ui-fabric',
#  'stackmob',
#  'yii',
#  'web-crawler',
#  'zurb-foundation-6',
#  'collapsable',
#  'ole',
#  'ng-options',
#  'google-sheets-api',
#  'nouislider',
#  'wechat',
#  'react-proptypes',
#  'blockly',
#  'css-transforms',
#  'canvas',
#  'content-script',
#  'media-queries',
#  'octobercms',
#  'chromeless',
#  'symfony-1.4',
#  'elfinder',
#  'location',
#  'ionic-v1',
#  'save',
#  'ionic2',
#  'laravel-5.4',
#  'ember.js',
#  'cakephp',
#  'qooxdoo',
#  'scrollspy',
#  'touch',
#  'element-ui',
#  'popper.js',
#  'https',
#  'voiceover',
#  'twitter-bootstrap-4',
#  'beautifulsoup',
#  'extreact',
#  'wp-nav-walker',
#  'webpage',
#  'handlebars.js',
#  'tree',
#  'magento',
#  'magento-1.7',
#  'row',
#  'kendo-contextmenu',
#  'extjs3',
#  'rotation',
#  'drupal',
#  'drupal-navigation',
#  'fabricjs',
#  'conditional',
#  'classiejs',
#  'gallery',
#  'contenteditable',
#  'sigma.js',
#  'document',
#  'innerhtml',
#  'ng2-charts',
#  'html-input',
#  'mathjax',
#  'file',
#  'routes',
#  'config',
#  'polymer-1.0',
#  'mean',
#  'meanjs',
#  'genesis',
#  'jtabbedpane',
#  'bootstrap-tour',
#  'polymer-elements',
#  'database',
#  'eloquent',
#  'richtextbox',
#  'syncfusion',
#  'string',
#  'algorithm',
#  'css-grid',
#  'datepicker',
#  'openlayers',
#  'aurelia',
#  'angular2-services',
#  'oajax.js',
#  'adobe-illustrator',
#  'anchor',
#  'powerbi-embedded',
#  'tinymce-plugins',
#  'material-design-lite',
#  'local-storage',
#  'delicious-api',
#  'dynamic',
#  'coffeescript',
#  'preventdefault',
#  'codepen',
#  'jquery-animate',
#  'nw.js',
#  'fixed',
#  'semantic-markup',
#  'background',
#  'gis',
#  'leaflet.draw',
#  'suitescript2.0',
#  'image',
#  'phalcon',
#  'charts',
#  'google-visualization',
#  'setattribute',
#  'menu-items',
#  'response',
#  'switch-statement',
#  'textfield',
#  'polymer-2.x',
#  'mutation',
#  'width',
#  'plotly',
#  'microsoft-edge',
#  'options',
#  'casperjs',
#  'prestashop',
#  'cycle2',
#  'graphics',
#  'alert',
#  'firebase',
#  'firebase-realtime-database',
#  'ngroute',
#  'border',
#  'offset',
#  'macos',
#  'twitter',
#  'asset-pipeline',
#  'prestashop-1.6',
#  'treeview',
#  'automated-tests',
#  'css-float',
#  'liquid-layout',
#  'azure',
#  'applescript',
#  'google-docs',
#  'attributes',
#  'title',
#  'reverse-geocoding',
#  'components',
#  'html5-video',
#  'ag-grid-ng2',
#  'onepage-scroll',
#  'message-passing',
#  'devextreme',
#  'angular-ngmodel',
#  'ng-controller',
#  'indexof',
#  'getelementsbyclassname',
#  'highstock',
#  'angular2-template',
#  'angular2-routing',
#  'ms-office',
#  'angular-routing',
#  'asp.net-mvc-5',
#  'angular-material2',
#  'jquery-ui-contextmenu',
#  'calendar',
#  'angular-ui-grid',
#  'ui-grid',
#  'bind',
#  'unbind',
#  'datetime',
#  'tablesorter',
#  'kendo-asp.net-mvc',
#  'cytoscape.js',
#  'jquery-context',
#  'flash',
#  'angularjs-directive',
#  'testing',
#  'nightwatch.js',
#  'ajaxform',
#  'multi-level',
#  'xpath',
#  'css-selectors',
#  'node-webkit',
#  'nwjs',
#  'clipboard',
#  'twitter-bootstrap-2',
#  'prototype',
#  'sessionstorage',
#  'facebook-graph-api',
#  'heroku',
#  'dhtmlx',
#  'google-spreadsheet-api',
#  'ionic',
#  'user-generated-content',
#  'blogspot',
#  'ngtable',
#  'angularjs-scope',
#  'algolia',
#  'rich-text-editor',
#  'admin-on-rest',
#  'gantt-chart',
#  'textbox',
#  'intellij-idea',
#  'libraries',
#  'objective-c',
#  'wkwebview',
#  'contact-form',
#  'tablet',
#  'jquery-validate',
#  'webforms',
#  'toolstrip',
#  'http',
#  'position',
#  'angular-ng-if',
#  'force-layout',
#  'mobile-browser',
#  'footer',
#  'marko',
#  'height',
#  'volusion',
#  'java-ee-7',
#  'reference',
#  'element',
#  'sharepoint-2013',
#  'usability',
#  'csv',
#  'null',
#  'windows-key',
#  'shopify',
#  'cesium',
#  'tablerow',
#  'react-dom',
#  'titanium',
#  'appcelerator',
#  'titanium-alloy',
#  'asp.net-4.0',
#  'javascript-events',
#  'drilldown',
#  'facebook',
#  'visual-studio',
#  'toggleclass',
#  'summary',
#  'review',
#  'affix',
#  'opencart',
#  'gridview',
#  'debugging',
#  'target',
#  'jsf',
#  'primefaces',
#  'paper-elements',
#  'google-material-icons',
#  'google-fusion-tables',
#  'post',
#  'iron-router',
#  'jquery-plugins',
#  'pdf',
#  'acrobat',
#  'telerik',
#  'radgrid',
#  'laravel-5.2',
#  'addclass',
#  'removeclass',
#  'system-tray',
#  'appcelerator-titanium',
#  'appcelerator-studio',
#  'extjs6-modern',
#  '.net',
#  'swipe',
#  'panel',
#  'webix',
#  'hidden',
#  'expandable',
#  'md-autocomplete',
#  'modernizr',
#  'slice',
#  'grid',
#  'jquery-isotope',
#  'magellan',
#  'yii2',
#  'render',
#  'append',
#  'autofill',
#  'razor',
#  'react-native-android',
#  'targeting',
#  'cookies',
#  'joomla3.4',
#  'global-variables',
#  'syntax',
#  'opera',
#  'symfony',
#  'sql',
#  'c3.js',
#  'webdriver',
#  'html5-canvas',
#  'crosswalk-runtime',
#  'dhtml',
#  'regex',
#  'notifications',
#  'swift',
#  'tvos',
#  'apple-tv',
#  'tvml',
#  'kendo-menu',
#  'jasny-bootstrap',
#  'phonegap-build',
#  'hybrid-mobile-app',
#  'bootstrap-tabs',
#  'mootools',
#  'sidr',
#  'jquery-mobile-collapsible',
#  'export',
#  'data-visualization',
#  'fadein',
#  'fadeout',
#  'background-color',
#  'alpha',
#  'queue',
#  'mvvm',
#  'horizontal-scrolling',
#  'back-button',
#  'onsen-ui',
#  'monaca',
#  'xhtml',
#  'slideshow',
#  'chart.js',
#  'session-storage',
#  'spring',
#  'ionic-view',
#  'screen-readers',
#  'nvda',
#  'dreamweaver',
#  'jquery-ui-dialog',
#  'air',
#  'meteor-blaze',
#  'spacebars',
#  'off-screen',
#  'xpages',
#  'lotus-domino',
#  'win-universal-app',
#  'winjs',
#  'internet-explorer-9',
#  'custom-contextmenu',
#  'keyboard-navigation',
#  'fullscreen',
#  'fancybox',
#  'web-inspector',
#  'masonry',
#  'geometry',
#  'miva',
#  'w2ui',
#  'video.js',
#  'phantomjs',
#  'widget',
#  'typeerror',
#  'listview',
#  'ember-data',
#  'overflow',
#  'window-resize',
#  'marquee',
#  'angular-ui',
#  'suckerfish',
#  'vb.net',
#  'visual-studio-2005',
#  'jquery-selectric',
#  'xul',
#  'hybrid',
#  'game-engine',
#  'phaser-framework',
#  'trello',
#  'jssor',
#  'replaceall',
#  'breadcrumbs',
#  'yui-pure-css',
#  'repeater',
#  'content-management-system',
#  'blogs',
#  'jqgrid',
#  'translation',
#  'focusout',
#  'dashboard',
#  'parse-platform',
#  'mention',
#  'pagination',
#  'jquery-select2-4',
#  'select2',
#  'bootstrap-accordion',
#  'unslider',
#  'setvalue',
#  'jquery-ui-datepicker',
#  'session',
#  'angular-strap',
#  'i18next',
#  'asp.net-web-api',
#  'backbone.js',
#  'end-to-end',
#  'browser-addons',
#  'ui-design',
#  'oracle-apex-5',
#  'mapbox',
#  'alertifyjs',
#  'gwt',
#  'ime',
#  'angularjs-ng-route',
#  'nav-pills',
#  'onmouseover',
#  'mouseover',
#  'dgrid',
#  'visual-studio-2015',
#  'office365',
#  'sharepoint-online',
#  'sharepoint-apps',
#  'umbraco',
#  'ember-cli',
#  'ghost-blog',
#  'src',
#  'onblur',
#  'kendo-scheduler',
#  'blur',
#  'mozilla',
#  'push',
#  'lavalamp',
#  'visual-studio-2013',
#  'jquery-ui-menu',
#  'selected',
#  'overlap',
#  'hidden-field',
#  'multi-select',
#  'gruntjs',
#  'drupal-modules',
#  'bigcommerce',
#  'slidingmenu',
#  'trigonometry',
#  'pi',
#  'zurb-foundation-5',
#  'mean-stack',
#  'prototypejs',
#  'ab-testing',
#  'google-experiments',
#  'devexpress',
#  'opera-extension',
#  'select-menu',
#  'iconic',
#  'javascriptmvc',
#  'controller',
#  'directive',
#  'truncate',
#  'jakarta-ee',
#  'angularjs-bootstrap',
#  'flip',
#  'bourbon',
#  'neat',
#  'ng-grid',
#  'hotkeys',
#  'applet',
#  'ubuntu-14.04',
#  'asp.net-mvc-3',
#  'onmousedown',
#  'chained-select',
#  'chained',
#  'mouseleave',
#  'filtering',
#  'selectize.js',
#  'custom-data-attribute',
#  'selectors-api',
#  'font-family',
#  'jquery-datatables',
#  'intel-xdk',
#  'google-caja',
#  'parallax',
#  'skrollr',
#  'angular-leaflet-directive',
#  'migration',
#  'upgrade',
#  'angularjs-ng-show',
#  'embed',
#  ...]

# %%
question_ids = data['question_id'].unique()

# %%
missing_question_ids = data[data["answer_text"] == ""]['question_id'].unique()

# %%
len(question_ids)
# Out:
# 32597

# %%
data.iloc[119310]
# Out:
# tags                                                          html
# question_id                                               58826520
# title            JavaScript code causes &lt;header&gt; and &lt;...
# label                                                       header
# answer_id                                                 58826670
# question_text    I am working on a webpage where scripts in bot...
# question_code    <script>\nfunction myFunction(e) {\n      var ...
# answer_text      When you use document.body.innerHTML = string;...
# answer_code      $$$$$$$$$$$$$$$$$$$$$$$$$$$$$ javascript\ndocu...
# Name: 1, dtype: object

# %%
url = "https://stackoverflow.com/questions/65343246/"
result = requests.get(url)
soup = BeautifulSoup(result.content, 'html.parser')
# print(soup.prettify())
div = soup.find("div", id="answer-65343410")
code = div.find_all('code')

# %%
def update_answer_code(question_id, answer_id):
    print("answer is ", answer_id)
    url = "https://stackoverflow.com/questions/" + str(question_id) + "/"
    result = requests.get(url)
    soup = BeautifulSoup(result.content, 'html.parser')
    
    answer = "answer-" + str(answer_id)
    answer_div = soup.find("div", id=answer)
    if(not answer_div):
        print("blocked")
        time.sleep(1000)
        url = "https://stackoverflow.com/questions/" + str(question_id) + "/"
        result = requests.get(url)
        soup = BeautifulSoup(result.content, 'html.parser')
        answer_div = soup.find("div", id=answer)
        while(not answer_div):
            print("blocked again")
            time.sleep(120)
            url = "https://stackoverflow.com/questions/" + str(question_id) + "/"
            result = requests.get(url)
            soup = BeautifulSoup(result.content, 'html.parser')
            answer_div = soup.find("div", id=answer)
        
    answer_code = answer_div.find_all("code")
    a_code = ""
    for a_c in answer_code:
        lang = "undefined"
        current_snippet = str(a_c.text)
        
        
        if(re.search("</\w+>", current_snippet)):
            lang = "html"
        elif(re.search(":", current_snippet)):
            #could be javascript still so we must make sure that it is not
            if not (re.search("var|const|\(\)|return|=", current_snippet)):
                lang = "css"
            else:
                lang = "javascript"
        elif (re.search("var|const|\(\)|return|=", current_snippet)):
            lang = "javascript"
            
        delimiter = "$$$$$$$$$$$$$$$$$$$$$$$$$$$$$ " + lang + "\n"
        a_code += delimiter + current_snippet + "\n"
    return a_code

# %%
def get_code(question_id, answer_id):
    url = "https://stackoverflow.com/questions/" + str(question_id) + "/"
    result = requests.get(url)
    soup = BeautifulSoup(result.content, 'html.parser')
    answer = "answer-" + str(answer_id)
    div = soup.find("div", id=answer)
    print("div is ", question_id, div)
    code = div.find_all('code')
    result = ""
    for c in code:
        result += str(c.text)
    return result

# %%
def get_question_and_answer_text(question_id, answer_id):
    url = "https://stackoverflow.com/questions/" + str(question_id) + "/"
    result = requests.get(url)
    soup = BeautifulSoup(result.content, 'html.parser')
    
    answer = "answer-" + str(answer_id)
    question_div = soup.find("div", class_="s-prose js-post-body")
    question_text = question_div.find_all("p")
    question_code = question_div.find_all("code")
    answer_div = soup.find("div", id=answer)
    answer_text = answer_div.find_all("p")
    answer_code = answer_div.find_all("code")
    q_text = ""
    q_code = ""
    a_text = ""
    a_code = ""
    for q_t in question_text:
        q_text += str(q_t.text)
    for q_c in question_code:
        q_code += str(q_c.text)
    for a_t in answer_text:
        a_text += str(a_t.text)
    for a_c in answer_code:
        lang = "undefined"
        current_snippet = str(a_c.text)
        if(re.search("</\w+>", current_snippet)):
            lang = "html"
        elif(re.search(":", current_snippet)):
            #could be javascript still so we must make sure that it is not
            if not (re.search("var|const|\(\)|return|=", current_snippet)):
                lang = "css"
            else:
                lang = "javascript"
        elif (re.search("var|const|\(\)|return|=", current_snippet)):
            lang = "javascript"
            
        delimiter = "$$$$$$$$$$$$$$$$$$$$$$$$$$$$$ " + lang + "\n"
        a_code += delimiter + current_snippet + "\n"
    return q_text, q_code, a_text, a_code

# %%
for question in question_ids:
    answer_id = data['answer_id'][data['question_id'] == question].unique()[0]
    print("question is ", question)
    get_question_and_answer_text(question, answer_id)
    print()
# Out:
# question is  36871635
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-03e7a6def2f9> in <module>
#       3     answer_id = data['answer_id'][data['question_id'] == question].unique()[0]
#       4     print("question is ", question)
# ----> 5     get_question_and_answer_text(question, answer_id)
#       6     print()
#       7     count += 1
#
# NameError: name 'get_question_and_answer_text' is not defined

# %%
for question in question_ids:
    answer_id = data['answer_id'][data['question_id'] == question].unique()[0]
    print("question is ", question)
    q_text, q_code, a_text, a_code = get_question_and_answer_text(question, answer_id)
    data['question_text'][data['question_id'] == question] = q_text
    data['question_code'][data['question_id'] == question] = q_code
    data['answer_text'][data['question_id'] == question] = a_text
    data['answer_code'][data['question_id'] == question] = a_code

# %%
#update answer code
count = 0
for question in question_ids[22619:]:
    answer_id = data['answer_id'][data['question_id'] == question].unique()[0]
    print("question is ", question)
    a_code = update_answer_code(question, answer_id)
    data['answer_code'][data['question_id'] == question] = a_code
    count += 1
    print(count)
    print("\n")
# Out:
# question is  38228502
# answer is  38229002
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 1
#
#
# question is  38220211
# answer is  38225393
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 2
#
#
# question is  38176740
# answer is  38216031
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 3
#
#
# question is  38210888
# answer is  38210981
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 4
#
#
# question is  38203258
# answer is  38203528
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 5
#
#
# question is  38200821
# answer is  38200893
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 6
#
#
# question is  7738903
# answer is  7738929
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 7
#
#
# question is  38103534
# answer is  38167515
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 8
#
#
# question is  38190377
# answer is  38190385
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 9
#
#
# question is  38188729
# answer is  38188895
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 10
#
#
# question is  38182236
# answer is  38182273
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 11
#
#
# question is  38185272
# answer is  38185465
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 12
#
#
# question is  5797661
# answer is  13468521
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 13
#
#
# question is  38182472
# answer is  38182572
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 14
#
#
# question is  38181147
# answer is  38181209
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 15
#
#
# question is  38175665
# answer is  38175820
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 16
#
#
# question is  38173548
# answer is  38173577
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 17
#
#
# question is  34952304
# answer is  38166591
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 18
#
#
# question is  25493706
# answer is  25496793
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 19
#
#
# question is  38174655
# answer is  38174953
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 20
#
#
# question is  38174587
# answer is  38174709
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 21
#
#
# question is  38172556
# answer is  38173845
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 22
#
#
# question is  1750681
# answer is  1750717
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 23
#
#
# question is  38166525
# answer is  38166611
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 24
#
#
# question is  38165773
# answer is  38165796
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 25
#
#
# question is  38139362
# answer is  38139396
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 26
#
#
# question is  38154201
# answer is  38154357
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 27
#
#
# question is  38153474
# answer is  38153535
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 28
#
#
# question is  38131762
# answer is  38138233
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 29
#
#
# question is  3842567
# answer is  3842595
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 30
#
#
# question is  9398574
# answer is  9398805
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 31
#
#
# question is  38136835
# answer is  38136936
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 32
#
#
# question is  38136716
# answer is  38136729
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 33
#
#
# question is  38123664
# answer is  38124128
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 34
#
#
# question is  38130291
# answer is  38132627
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 35
#
#
# question is  38130903
# answer is  38131768
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 36
#
#
# question is  38117832
# answer is  38129151
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 37
#
#
# question is  38127694
# answer is  38128802
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 38
#
#
# question is  37941846
# answer is  37941923
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 39
#
#
# question is  38108843
# answer is  38108950
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 40
#
#
# question is  38102032
# answer is  38103288
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 41
#
#
# question is  38078569
# answer is  38079506
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 42
#
#
# question is  38101307
# answer is  38101369
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 43
#
#
# question is  38100416
# answer is  38100470
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 44
#
#
# question is  38094654
# answer is  38099708
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 45
#
#
# question is  38097437
# answer is  38097817
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 46
#
#
# question is  38091505
# answer is  38091559
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 47
#
#
# question is  38087249
# answer is  38087328
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 48
#
#
# question is  38088175
# answer is  38088252
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 49
#
#
# question is  21968467
# answer is  21968517
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 50
#
#
# question is  38076671
# answer is  38076894
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 51
#
#
# question is  38068937
# answer is  38069000
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 52
#
#
# question is  7845543
# answer is  7845564
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 53
#
#
# question is  38064306
# answer is  38064515
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 54
#
#
# question is  38060602
# answer is  38063763
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 55
#
#
# question is  1626419
# answer is  1626634
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 56
#
#
# question is  37866549
# answer is  37927810
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 57
#
#
# question is  38042550
# answer is  38042608
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 58
#
#
# question is  38037978
# answer is  38038040
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 59
#
#
# question is  38034735
# answer is  38034813
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 60
#
#
# question is  38016513
# answer is  38034363
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 61
#
#
# question is  38033634
# answer is  38033672
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 62
#
#
# question is  38031167
# answer is  38031371
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 63
#
#
# question is  38019573
# answer is  38019696
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 64
#
#
# question is  38027655
# answer is  38027671
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 65
#
#
# question is  38029143
# answer is  38029202
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 66
#
#
# question is  38027955
# answer is  38028139
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 67
#
#
# question is  38027498
# answer is  38027778
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 68
#
#
# question is  38027495
# answer is  38027647
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 69
#
#
# question is  15545542
# answer is  15545586
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 70
#
#
# question is  24849220
# answer is  38015339
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 71
#
#
# question is  38014429
# answer is  38014764
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 72
#
#
# question is  2186041
# answer is  2186056
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 73
#
#
# question is  38005089
# answer is  38005107
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 74
#
#
# question is  37723921
# answer is  38002918
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 75
#
#
# question is  37995581
# answer is  37995692
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 76
#
#
# question is  37994158
# answer is  37994789
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 77
#
#
# question is  37339229
# answer is  37349208
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 78
#
#
# question is  37971354
# answer is  37974074
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 79
#
#
# question is  37953076
# answer is  37971446
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 80
#
#
# question is  37965568
# answer is  37965764
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 81
#
#
# question is  37957781
# answer is  37963420
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 82
#
#
# question is  37960781
# answer is  37960955
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 83
#
#
# question is  37881668
# answer is  37887642
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 84
#
#
# question is  37891360
# answer is  37953376
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 85
#
#
# question is  37950062
# answer is  37950202
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 86
#
#
# question is  37943054
# answer is  37945750
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 87
#
#
# question is  28595742
# answer is  28618965
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 88
#
#
# question is  37942319
# answer is  37942647
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 89
#
#
# question is  37944837
# answer is  37945403
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 90
#
#
# question is  37944376
# answer is  37945241
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 91
#
#
# question is  35461636
# answer is  37944792
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 92
#
#
# question is  37933447
# answer is  37933510
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 93
#
#
# question is  34051762
# answer is  34057467
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 94
#
#
# question is  37934530
# answer is  37934609
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 95
#
#
# question is  37930873
# answer is  37931177
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 96
#
#
# question is  37887901
# answer is  37888214
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 97
#
#
# question is  37907074
# answer is  37918992
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 98
#
#
# question is  37896743
# answer is  37902746
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 99
#
#
# question is  37909780
# answer is  37910586
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 100
#
#
# question is  31802903
# answer is  31825537
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 101
#
#
# question is  37905501
# answer is  37906252
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 102
#
#
# question is  37899090
# answer is  37899120
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 103
#
#
# question is  12959199
# answer is  13138505
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 104
#
#
# question is  37874182
# answer is  37891901
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 105
#
#
# question is  22715036
# answer is  22715113
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 106
#
#
# question is  37870770
# answer is  37870933
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 107
#
#
# question is  37873211
# answer is  37873721
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 108
#
#
# question is  19480052
# answer is  19483993
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 109
#
#
# question is  37871312
# answer is  37871567
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 110
#
#
# question is  37870631
# answer is  37870791
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 111
#
#
# question is  37866323
# answer is  37866597
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 112
#
#
# question is  37863357
# answer is  37863890
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 113
#
#
# question is  37860916
# answer is  37860943
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 114
#
#
# question is  37858132
# answer is  37859537
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 115
#
#
# question is  37325758
# answer is  37329039
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 116
#
#
# question is  37856801
# answer is  37857126
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 117
#
#
# question is  37851402
# answer is  37851475
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 118
#
#
# question is  37840780
# answer is  37849139
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 119
#
#
# question is  37806462
# answer is  37848097
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 120
#
#
# question is  37834917
# answer is  37835005
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 121
#
#
# question is  37831303
# answer is  37832877
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 122
#
#
# question is  22224841
# answer is  22225431
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 123
#
#
# question is  37809376
# answer is  37812417
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 124
#
#
# question is  37654671
# answer is  37654915
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 125
#
#
# question is  37826286
# answer is  37827601
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 126
#
#
# question is  37788389
# answer is  37788634
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 127
#
#
# question is  37825999
# answer is  37826056
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# ...
#   data['answer_code'][data['question_id'] == question] = a_code
# 2461
#
#
# question is  30521579
# answer is  30521631
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 2462
#
#
# question is  30520582
# answer is  30520644
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 2463
#
#
# question is  30519845
# answer is  30520101
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 2464
#
#
# question is  15178550
# answer is  15193865
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 2465
#
#
# question is  30503311
# answer is  30503997
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 2466
#
#
# question is  30513457
# answer is  30513545
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 2467
#
#
# question is  30513947
# answer is  30515463
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 2468
#
#
# question is  30510150
# answer is  30510758
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 2469
#
#
# question is  30509602
# answer is  30509845
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 2470
#
#
# question is  30504883
# answer is  30504936
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 2471
#
#
# question is  30494820
# answer is  30494877
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 2472
#
#
# question is  30497562
# answer is  30498580
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 2473
#
#
# question is  30493021
# answer is  30493387
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 2474
#
#
# question is  30492229
# answer is  30492405
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 2475
#
#
# question is  30490881
# answer is  30491441
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 2476
#
#
# question is  30488534
# answer is  30488573
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 2477
#
#
# question is  30484348
# answer is  30484766
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 2478
#
#
# question is  30481311
# answer is  30481758
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 2479
#
#
# question is  17484097
# answer is  30478216
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 2480
#
#
# question is  30476919
# answer is  30477149
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 2481
#
#
# question is  30474892
# answer is  30476817
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 2482
#
#
# question is  30467848
# answer is  30468685
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 2483
#
#
# question is  18873807
# answer is  18873877
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 2484
#
#
# question is  30075722
# answer is  30456163
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 2485
#
#
# question is  30454688
# answer is  30455539
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 2486
#
#
# question is  30375578
# answer is  30392126
# <ipython-input-11-e9c745c4b3f6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['answer_code'][data['question_id'] == question] = a_code
# 2487
#
#
# question is  30453035
# answer is  30453081
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-e9c745c4b3f6> in <module>
#       4     answer_id = data['answer_id'][data['question_id'] == question].unique()[0]
#       5     print("question is ", question)
# ----> 6     a_code = update_answer_code(question, answer_id)
#       7     data['answer_code'][data['question_id'] == question] = a_code
#       8     count += 1
#
# <ipython-input-6-a7f11a557841> in update_answer_code(question_id, answer_id)
#       2     print("answer is ", answer_id)
#       3     url = "https://stackoverflow.com/questions/" + str(question_id) + "/"
# ----> 4     result = requests.get(url)
#       5     soup = BeautifulSoup(result.content, 'html.parser')
#       6
#
# ~/Documents/Christmas/venv/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~/Documents/Christmas/venv/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~/Documents/Christmas/venv/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~/Documents/Christmas/venv/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~/Documents/Christmas/venv/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~/Documents/Christmas/venv/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# ~/Documents/Christmas/venv/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380         # Trigger any extra validation we need to do.
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#     384             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~/Documents/Christmas/venv/lib/python3.8/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#    1008         # Force connect early to allow us to validate the connection.
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1010             conn.connect()
#    1011
#    1012         if not conn.is_verified:
#
# ~/Documents/Christmas/venv/lib/python3.8/site-packages/urllib3/connection.py in connect(self)
#     409             context.load_default_certs()
#     410
# --> 411         self.sock = ssl_wrap_socket(
#     412             sock=conn,
#     413             keyfile=self.key_file,
#
# ~/Documents/Christmas/venv/lib/python3.8/site-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     426
#     427     if send_sni:
# --> 428         ssl_sock = _ssl_wrap_socket_impl(
#     429             sock, context, tls_in_tls, server_hostname=server_hostname
#     430         )
#
# ~/Documents/Christmas/venv/lib/python3.8/site-packages/urllib3/util/ssl_.py in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     470
#     471     if server_hostname:
# --> 472         return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     473     else:
#     474         return ssl_context.wrap_socket(sock)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     498         # SSLSocket class handles server_hostname encoding before it calls
#     499         # ctx._wrap_socket()
# --> 500         return self.sslsocket_class._create(
#     501             sock=sock,
#     502             server_side=server_side,
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1038                         # non-blocking
#    1039                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040                     self.do_handshake()
#    1041             except (OSError, ValueError):
#    1042                 self.close()
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/ssl.py in do_handshake(self, block)
#    1307             if timeout == 0.0 and block:
#    1308                 self.settimeout(None)
# -> 1309             self._sslobj.do_handshake()
#    1310         finally:
#    1311             self.settimeout(timeout)
#
# KeyboardInterrupt:

# %% [markdown]
# # list(data["answer_code"])[0]

# %%
len(missing_question_ids)
# Out:
# 28624

# %%
missing_question_ids
# Out:
# array([12315607, 13411992,  1460259, 65203514, 64746658, 59398244,
#        64763994, 64791808, 64505510, 64437803, 64009823, 64159310,
#        63920197, 63792104, 63673317, 54337639, 62457679, 57836805,
#        63467957, 64592458, 34743617, 35864538, 64448576, 64277571,
#        64191883, 64188653, 64128198, 64106717, 63924239, 63633063,
#        63783831, 63632164, 63557030, 63503432, 63407380, 63008479,
#        43526607, 63323021, 37527962, 63225061, 63215216, 63137670,
#        59872650, 58059650, 62902860, 54646733, 28547288, 62500960,
#        24353015, 57422451, 20825508, 61910056, 66141095, 65961775,
#        65842156, 65614187, 65545678, 65782263, 65991305, 65715713,
#        27010834, 20035101, 58005954, 65271199, 65355332, 65273191,
#        64468159, 49253245, 42345641, 39066786, 65738914, 64295062,
#        64602179, 63280440, 42096405, 48412934, 55690777, 27641978,
#        51195730, 14847757, 10553784, 30663405, 38915240, 33428974,
#        30327193, 30209611, 29467125, 23683288, 65668602, 24323475,
#        64574049, 64177729, 64050566, 62187400, 60003616, 59707942,
#        58400302, 56843151,   255534, 57514074, 55945371, 44469915,
#        14294035, 66140849, 63979946, 65062719, 64843392, 63416900,
#        24434062, 63010501, 62415360, 65620437, 64519229,   429107,
#        63767906, 31960575, 59981152, 52453512, 58052043, 35301005,
#        54304048, 25618166, 53979140, 53966138, 44142625, 52668746,
#        48135663, 46117076, 46033903, 44331630, 44517650, 21728775,
#        43265611, 31289530, 42699434, 41155283, 40343391, 38883730,
#        34013360, 33973885, 32964259, 32866165, 32620892, 31298880,
#        31142609, 29552071, 26312260, 26171037,  6896980, 25477474,
#         9125080,  4515405, 23262396, 22439371, 61011198, 57469853,
#        56029078, 50596493, 46632609, 49593603, 49043877, 42216902,
#        39315504, 20351977, 35379817, 32719762, 62986720, 48423876,
#        62794477, 52173134, 62507887, 62009474, 61878426, 61591880,
#        61615072, 47387590, 61720544, 61605209, 60262933, 57253460,
#        11664686, 55198506, 60826837, 60811101, 18948527, 53787814,
#        23181380, 19382431, 60060345, 59972159, 59910684, 42351491,
#        47691404, 16398885, 19354985, 59486699, 59454007, 25987836,
#        59444653, 31579766, 59144798, 33339906, 58960720, 52223129])

# %%
result = ""
for c in code:
    result += str(c.text)

print(result)
# Out:
# const handleMenuOpen = (e) => {
#     setAnchorEl(e.currentTarget); // for menu placement
#     setItemID(e.currentTarget.id);
# };
#
#
# <MenuItem onClick={handleMenuOpen} />;

# %%
data.to_pickle("./pages15_on")
